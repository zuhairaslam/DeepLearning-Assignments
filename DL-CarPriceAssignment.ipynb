# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/drive/MyDrive/Data/CarPrice_Assignment.csv")

# %%
data.head()
# Out:
#    car_ID  symboling                   CarName  ... citympg highwaympg    price
# 0       1          3        alfa-romero giulia  ...      21         27  13495.0
# 1       2          3       alfa-romero stelvio  ...      21         27  16500.0
# 2       3          1  alfa-romero Quadrifoglio  ...      19         26  16500.0
# 3       4          2               audi 100 ls  ...      24         30  13950.0
# 4       5          2                audi 100ls  ...      18         22  17450.0
#
# [5 rows x 26 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.8+ KB

# %%
data['CarName'].unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
#        'mazda glc deluxe', 'mazda 626', 'mazda glc', 'mazda rx-7 gs',
#        'mazda glc 4', 'mazda glc custom l', 'mazda glc custom',
#        'buick electra 225 custom', 'buick century luxus (sw)',
#        'buick century', 'buick skyhawk', 'buick opel isuzu deluxe',
#        'buick skylark', 'buick century special',
#        'buick regal sport coupe (turbo)', 'mercury cougar',
#        'mitsubishi mirage', 'mitsubishi lancer', 'mitsubishi outlander',
#        'mitsubishi g4', 'mitsubishi mirage g4', 'mitsubishi montero',
#        'mitsubishi pajero', 'Nissan versa', 'nissan gt-r', 'nissan rogue',
#        'nissan latio', 'nissan titan', 'nissan leaf', 'nissan juke',
#        'nissan note', 'nissan clipper', 'nissan nv200', 'nissan dayz',
#        'nissan fuga', 'nissan otti', 'nissan teana', 'nissan kicks',
#        'peugeot 504', 'peugeot 304', 'peugeot 504 (sw)', 'peugeot 604sl',
#        'peugeot 505s turbo diesel', 'plymouth fury iii',
#        'plymouth cricket', 'plymouth satellite custom (sw)',
#        'plymouth fury gran sedan', 'plymouth valiant', 'plymouth duster',
#        'porsche macan', 'porcshce panamera', 'porsche cayenne',
#        'porsche boxter', 'renault 12tl', 'renault 5 gtl', 'saab 99e',
#        'saab 99le', 'saab 99gle', 'subaru', 'subaru dl', 'subaru brz',
#        'subaru baja', 'subaru r1', 'subaru r2', 'subaru trezia',
#        'subaru tribeca', 'toyota corona mark ii', 'toyota corona',
#        'toyota corolla 1200', 'toyota corona hardtop',
#        'toyota corolla 1600 (sw)', 'toyota carina', 'toyota mark ii',
#        'toyota corolla', 'toyota corolla liftback',
#        'toyota celica gt liftback', 'toyota corolla tercel',
#        'toyota corona liftback', 'toyota starlet', 'toyota tercel',
#        'toyota cressida', 'toyota celica gt', 'toyouta tercel',
#        'vokswagen rabbit', 'volkswagen 1131 deluxe sedan',
#        'volkswagen model 111', 'volkswagen type 3', 'volkswagen 411 (sw)',
#        'volkswagen super beetle', 'volkswagen dasher', 'vw dasher',
#        'vw rabbit', 'volkswagen rabbit', 'volkswagen rabbit custom',
#        'volvo 145e (sw)', 'volvo 144ea', 'volvo 244dl', 'volvo 245',
#        'volvo 264gl', 'volvo diesel', 'volvo 246'], dtype=object)

# %%
data.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.8+ KB

# %%
#correction: removing space from a value
data.iloc[3,3] = 'audi1001s'

# %%
data.head(10)
# Out:
#    car_ID  symboling                   CarName  ... citympg highwaympg      price
# 0       1          3        alfa-romero giulia  ...      21         27  13495.000
# 1       2          3       alfa-romero stelvio  ...      21         27  16500.000
# 2       3          1  alfa-romero Quadrifoglio  ...      19         26  16500.000
# 3       4          2               audi 100 ls  ...      24         30  13950.000
# 4       5          2                audi 100ls  ...      18         22  17450.000
# 5       6          2                  audi fox  ...      19         25  15250.000
# 6       7          1                audi 100ls  ...      19         25  17710.000
# 7       8          1                 audi 5000  ...      19         25  18920.000
# 8       9          1                 audi 4000  ...      17         20  23875.000
# 9      10          0       audi 5000s (diesel)  ...      16         22  17859.167
#
# [10 rows x 26 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.8+ KB

# %%
data.drop(columns=['car_ID'], inplace = True)

# %%
data.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
data1 = pd.get_dummies(data, columns= ['CarName', 'symboling', 'fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber', 'fuelsystem'], drop_first = True)

# %%
data1.describe()
# Out:
#         wheelbase   carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# count  205.000000  205.000000  ...       205.000000       205.000000
# mean    98.756585  174.049268  ...         0.043902         0.004878
# std      6.021776   12.337289  ...         0.205380         0.069843
# min     86.600000  141.100000  ...         0.000000         0.000000
# 25%     94.500000  166.300000  ...         0.000000         0.000000
# 50%     97.000000  173.200000  ...         0.000000         0.000000
# 75%    102.400000  183.100000  ...         0.000000         0.000000
# max    120.900000  208.100000  ...         1.000000         1.000000
#
# [8 rows x 195 columns]

# %%
data1.head()
# Out:
#    wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 0       88.6      168.8  ...                0                0
# 1       88.6      168.8  ...                0                0
# 2       94.5      171.2  ...                0                0
# 3       99.8      176.6  ...                0                0
# 4       99.4      176.6  ...                0                0
#
# [5 rows x 195 columns]

# %%
#taking 72 for 4 kfolds
np.random.seed(11111)
msk = np.random.rand(len(data1)) <0.72
train_total = data1[msk]
test_total = data1[~msk]

# %%
print(len(train_total))
print(len(test_total))
# Out:
# 141
# 64

# %%
train_total.head()
# Out:
#    wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 1       88.6      168.8  ...                0                0
# 2       94.5      171.2  ...                0                0
# 3       99.8      176.6  ...                0                0
# 4       99.4      176.6  ...                0                0
# 5       99.8      177.3  ...                0                0
#
# [5 rows x 195 columns]

# %%
train_total.describe()
# Out:
#         wheelbase   carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# count  141.000000  141.000000  ...       141.000000       141.000000
# mean    98.692199  173.658156  ...         0.035461         0.007092
# std      6.005665   12.320089  ...         0.185601         0.084215
# min     86.600000  144.600000  ...         0.000000         0.000000
# 25%     94.500000  166.300000  ...         0.000000         0.000000
# 50%     96.500000  172.400000  ...         0.000000         0.000000
# 75%    102.400000  180.300000  ...         0.000000         0.000000
# max    115.600000  202.600000  ...         1.000000         1.000000
#
# [8 rows x 195 columns]

# %%
print(train_total.dtypes)
# Out:
# wheelbase          float64
# carlength          float64
# carwidth           float64
# carheight          float64
# curbweight           int64
#                     ...
# fuelsystem_idi       uint8
# fuelsystem_mfi       uint8
# fuelsystem_mpfi      uint8
# fuelsystem_spdi      uint8
# fuelsystem_spfi      uint8
# Length: 195, dtype: object

# %%
train_label = train_total.loc[:,'price']
test_label = test_total.loc[:,'price']

# %%
train_label
# Out:
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
# 5      15250.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 141, dtype: float64

# %%
#Dropping price column from test dataset and training
test_data= test_total.drop(columns = ['price'])
train_data= train_total.drop(columns = ['price'])

# %%
train_data.shape[1]
# Out:
# 194

# %%
train_data
# Out:
#      wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 1         88.6      168.8  ...                0                0
# 2         94.5      171.2  ...                0                0
# 3         99.8      176.6  ...                0                0
# 4         99.4      176.6  ...                0                0
# 5         99.8      177.3  ...                0                0
# ..         ...        ...  ...              ...              ...
# 200      109.1      188.8  ...                0                0
# 201      109.1      188.8  ...                0                0
# 202      109.1      188.8  ...                0                0
# 203      109.1      188.8  ...                0                0
# 204      109.1      188.8  ...                0                0
#
# [141 rows x 194 columns]

# %%
train_data.shape
# Out:
# (141, 194)

# %%
{train_data.columns.get_loc(c): c for idx, c in enumerate(train_data.columns)}
# Out:
# {0: 'wheelbase',
#  1: 'carlength',
#  2: 'carwidth',
#  3: 'carheight',
#  4: 'curbweight',
#  5: 'enginesize',
#  6: 'boreratio',
#  7: 'stroke',
#  8: 'compressionratio',
#  9: 'horsepower',
#  10: 'peakrpm',
#  11: 'citympg',
#  12: 'highwaympg',
#  13: 'CarName_alfa-romero Quadrifoglio',
#  14: 'CarName_alfa-romero giulia',
#  15: 'CarName_alfa-romero stelvio',
#  16: 'CarName_audi 100 ls',
#  17: 'CarName_audi 100ls',
#  18: 'CarName_audi 4000',
#  19: 'CarName_audi 5000',
#  20: 'CarName_audi 5000s (diesel)',
#  21: 'CarName_audi fox',
#  22: 'CarName_bmw 320i',
#  23: 'CarName_bmw x1',
#  24: 'CarName_bmw x3',
#  25: 'CarName_bmw x4',
#  26: 'CarName_bmw x5',
#  27: 'CarName_bmw z4',
#  28: 'CarName_buick century',
#  29: 'CarName_buick century luxus (sw)',
#  30: 'CarName_buick century special',
#  31: 'CarName_buick electra 225 custom',
#  32: 'CarName_buick opel isuzu deluxe',
#  33: 'CarName_buick regal sport coupe (turbo)',
#  34: 'CarName_buick skyhawk',
#  35: 'CarName_buick skylark',
#  36: 'CarName_chevrolet impala',
#  37: 'CarName_chevrolet monte carlo',
#  38: 'CarName_chevrolet vega 2300',
#  39: 'CarName_dodge challenger se',
#  40: 'CarName_dodge colt (sw)',
#  41: 'CarName_dodge colt hardtop',
#  42: 'CarName_dodge coronet custom',
#  43: 'CarName_dodge coronet custom (sw)',
#  44: 'CarName_dodge d200',
#  45: 'CarName_dodge dart custom',
#  46: 'CarName_dodge monaco (sw)',
#  47: 'CarName_dodge rampage',
#  48: 'CarName_honda accord',
#  49: 'CarName_honda accord cvcc',
#  50: 'CarName_honda accord lx',
#  51: 'CarName_honda civic',
#  52: 'CarName_honda civic (auto)',
#  53: 'CarName_honda civic 1300',
#  54: 'CarName_honda civic 1500 gl',
#  55: 'CarName_honda civic cvcc',
#  56: 'CarName_honda prelude',
#  57: 'CarName_isuzu D-Max ',
#  58: 'CarName_isuzu D-Max V-Cross',
#  59: 'CarName_isuzu MU-X',
#  60: 'CarName_jaguar xf',
#  61: 'CarName_jaguar xj',
#  62: 'CarName_jaguar xk',
#  63: 'CarName_maxda glc deluxe',
#  64: 'CarName_maxda rx3',
#  65: 'CarName_mazda 626',
#  66: 'CarName_mazda glc',
#  67: 'CarName_mazda glc 4',
#  68: 'CarName_mazda glc custom',
#  69: 'CarName_mazda glc custom l',
#  70: 'CarName_mazda glc deluxe',
#  71: 'CarName_mazda rx-4',
#  72: 'CarName_mazda rx-7 gs',
#  73: 'CarName_mazda rx2 coupe',
#  74: 'CarName_mercury cougar',
#  75: 'CarName_mitsubishi g4',
#  76: 'CarName_mitsubishi lancer',
#  77: 'CarName_mitsubishi mirage',
#  78: 'CarName_mitsubishi mirage g4',
#  79: 'CarName_mitsubishi montero',
#  80: 'CarName_mitsubishi outlander',
#  81: 'CarName_mitsubishi pajero',
#  82: 'CarName_nissan clipper',
#  83: 'CarName_nissan dayz',
#  84: 'CarName_nissan fuga',
#  85: 'CarName_nissan gt-r',
#  86: 'CarName_nissan juke',
#  87: 'CarName_nissan kicks',
#  88: 'CarName_nissan latio',
#  89: 'CarName_nissan leaf',
#  90: 'CarName_nissan note',
#  91: 'CarName_nissan nv200',
#  92: 'CarName_nissan otti',
#  93: 'CarName_nissan rogue',
#  94: 'CarName_nissan teana',
#  95: 'CarName_nissan titan',
#  96: 'CarName_peugeot 304',
#  97: 'CarName_peugeot 504',
#  98: 'CarName_peugeot 504 (sw)',
#  99: 'CarName_peugeot 505s turbo diesel',
#  100: 'CarName_peugeot 604sl',
#  101: 'CarName_plymouth cricket',
#  102: 'CarName_plymouth duster',
#  103: 'CarName_plymouth fury gran sedan',
#  104: 'CarName_plymouth fury iii',
#  105: 'CarName_plymouth satellite custom (sw)',
#  106: 'CarName_plymouth valiant',
#  107: 'CarName_porcshce panamera',
#  108: 'CarName_porsche boxter',
#  109: 'CarName_porsche cayenne',
#  110: 'CarName_porsche macan',
#  111: 'CarName_renault 12tl',
#  112: 'CarName_renault 5 gtl',
#  113: 'CarName_saab 99e',
#  114: 'CarName_saab 99gle',
#  115: 'CarName_saab 99le',
#  116: 'CarName_subaru',
#  117: 'CarName_subaru baja',
#  118: 'CarName_subaru brz',
#  119: 'CarName_subaru dl',
#  120: 'CarName_subaru r1',
#  121: 'CarName_subaru r2',
#  122: 'CarName_subaru trezia',
#  123: 'CarName_subaru tribeca',
#  124: 'CarName_toyota carina',
#  125: 'CarName_toyota celica gt',
#  126: 'CarName_toyota celica gt liftback',
#  127: 'CarName_toyota corolla',
#  128: 'CarName_toyota corolla 1200',
#  129: 'CarName_toyota corolla 1600 (sw)',
#  130: 'CarName_toyota corolla liftback',
#  131: 'CarName_toyota corolla tercel',
#  132: 'CarName_toyota corona',
#  133: 'CarName_toyota corona hardtop',
#  134: 'CarName_toyota corona liftback',
#  135: 'CarName_toyota corona mark ii',
#  136: 'CarName_toyota cressida',
#  137: 'CarName_toyota mark ii',
#  138: 'CarName_toyota starlet',
#  139: 'CarName_toyota tercel',
#  140: 'CarName_toyouta tercel',
#  141: 'CarName_vokswagen rabbit',
#  142: 'CarName_volkswagen 1131 deluxe sedan',
#  143: 'CarName_volkswagen 411 (sw)',
#  144: 'CarName_volkswagen dasher',
#  145: 'CarName_volkswagen model 111',
#  146: 'CarName_volkswagen rabbit',
#  147: 'CarName_volkswagen rabbit custom',
#  148: 'CarName_volkswagen super beetle',
#  149: 'CarName_volkswagen type 3',
#  150: 'CarName_volvo 144ea',
#  151: 'CarName_volvo 145e (sw)',
#  152: 'CarName_volvo 244dl',
#  153: 'CarName_volvo 245',
#  154: 'CarName_volvo 246',
#  155: 'CarName_volvo 264gl',
#  156: 'CarName_volvo diesel',
#  157: 'CarName_vw dasher',
#  158: 'CarName_vw rabbit',
#  159: 'symboling_-1',
#  160: 'symboling_0',
#  161: 'symboling_1',
#  162: 'symboling_2',
#  163: 'symboling_3',
#  164: 'fueltype_diesel',
#  165: 'fueltype_gas',
#  166: 'aspiration_turbo',
#  167: 'doornumber_two',
#  168: 'carbody_hardtop',
#  169: 'carbody_hatchback',
#  170: 'carbody_sedan',
#  171: 'carbody_wagon',
#  172: 'drivewheel_fwd',
#  173: 'drivewheel_rwd',
#  174: 'enginelocation_rear',
#  175: 'enginetype_dohcv',
#  176: 'enginetype_l',
#  177: 'enginetype_ohc',
#  178: 'enginetype_ohcf',
#  179: 'enginetype_ohcv',
#  180: 'enginetype_rotor',
#  181: 'cylindernumber_five',
#  182: 'cylindernumber_four',
#  183: 'cylindernumber_six',
#  184: 'cylindernumber_three',
#  185: 'cylindernumber_twelve',
#  186: 'cylindernumber_two',
#  187: 'fuelsystem_2bbl',
#  188: 'fuelsystem_4bbl',
#  189: 'fuelsystem_idi',
#  190: 'fuelsystem_mfi',
#  191: 'fuelsystem_mpfi',
#  192: 'fuelsystem_spdi',
#  193: 'fuelsystem_spfi'}

# %%
#Normalizing Data

mean = train_data.iloc[:,0:13].mean(axis=0)
train_data.iloc[:,0:13] -= mean
std = train_data.iloc[:,0:13].std(axis=0)
train_data.iloc[:,0:13] /=std
test_data.iloc[:,0:13] -= mean
test_data.iloc[0,0:13] /= std

# %%
mean_label = train_label.mean()
train_label -= mean_label
std_label = train_label.std()
train_label /= std_label
test_label -= mean_label
test_label /= std_label

# %%
print(mean_label)
# Out:
# 13379.132390070921

# %%
print(std_label)
# Out:
# 8189.4945680106175

# %%
test_data.head(10)
# Out:
#     wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 0   -1.680447  -0.394328  ...                0                0
# 10   2.507801   3.141844  ...                0                0
# 14   4.807801  15.341844  ...                0                0
# 15   4.807801  15.341844  ...                0                0
# 18 -10.292199 -32.558156  ...                0                0
# 26  -4.992199 -16.358156  ...                0                0
# 27  -4.992199 -16.358156  ...                0                0
# 32  -4.992199 -23.658156  ...                0                0
# 34  -4.992199 -23.658156  ...                0                0
# 38  -2.192199  -6.158156  ...                0                0
#
# [10 rows x 194 columns]

# %%
mean
# Out:
# wheelbase             98.692199
# carlength            173.658156
# carwidth              65.875887
# carheight             53.648227
# curbweight          2546.787234
# enginesize           125.666667
# boreratio              3.324184
# stroke                 3.256809
# compressionratio      10.070355
# horsepower           103.702128
# peakrpm             5143.971631
# citympg               25.113475
# highwaympg            30.581560
# dtype: float64

# %%
std
# Out:
# wheelbase             6.005665
# carlength            12.320089
# carwidth              2.188604
# carheight             2.508204
# curbweight          529.769152
# enginesize           41.733451
# boreratio             0.266123
# stroke                0.296387
# compressionratio      3.868579
# horsepower           38.424275
# peakrpm             474.472458
# citympg               6.509435
# highwaympg            6.734937
# dtype: float64

# %%
#Storing in numpy-array

test = np.array(test_data.iloc[:]).astype('float32')
train = np.array(train_data.iloc[:]).astype('float32')
test_1 = np.array(test_label.astype('float32'))
train_1 = np.array(train_label.astype('float32'))

# %%
train.shape
# Out:
# (141, 194)

# %%
test.shape
# Out:
# (64, 194)

# %%
train.dtype
# Out:
# dtype('float32')

# %%
test.dtype
# Out:
# dtype('float32')

# %%
train.shape[1]
# Out:
# 194

# %%
test.shape[1]
# Out:
# 194

# %%
from keras import models
from keras import layers
def build_model(act):
  model = models.Sequential()
  model.add(layers.Dense(128, activation= act, input_shape=(train.shape[1],)))
  model.add(layers.Dense(64, activation= act))
  model.add(layers.Dense(32, activation= act))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mse'])
  return model

# %%
build_model('relu').summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_16 (Dense)             (None, 128)               24960
# _________________________________________________________________
# dense_17 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_18 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 35,329
# Trainable params: 35,329
# Non-trainable params: 0
# _________________________________________________________________

# %%
build_model('tanh').summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_20 (Dense)             (None, 128)               24960
# _________________________________________________________________
# dense_21 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_22 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 35,329
# Trainable params: 35,329
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras import regularizers
def build_model_regular(act):
  model = models.Sequential()
  model.add(layers.Dense(10, activation= act, kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001),input_shape=(train.shape[1],)))
  model.add(layers.Dense(8, activation=act, kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001)))
  model.add(layers.Dense(6, activation=act, kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001)))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model('relu').summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_24 (Dense)             (None, 128)               24960
# _________________________________________________________________
# dense_25 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_26 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_27 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 35,329
# Trainable params: 35,329
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Dropout Model
from keras import regularizers
def build_model_drop(act):
  model = models.Sequential()
  model.add(layers.Dense(10, activation=act, input_shape=(train.shape[1],)))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(8, activation=act))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(6, activation=act))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model_drop('relu').summary
# Out:
# <bound method Model.summary of <tensorflow.python.keras.engine.sequential.Sequential object at 0x7f843793ce90>>

# %%
# Kfold validation with relu 
# 141/4
import numpy as np
k = 4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_relu = []
for i in range(k):
  print('processing fold#', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_1[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples], train[(i+1) * num_val_samples:]], axis=0)
  #print(partial_train_data)
  partial_train_targets = np.concatenate([train_1[:i * num_val_samples],train_1[(i+1) * num_val_samples:]], axis=0)
  model = build_model('relu')
  model.fit(partial_train_data, partial_train_targets, epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data,val_targets,verbose=0)
  all_scores_relu.append(val_mae)
# Out:
# processing fold# 0
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_test_function.<locals>.test_function at 0x7f843791fcb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold# 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f8437a2f710> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold# 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f842efa35f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold# 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f8437c445f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
# Kfold validation with tanh 
# 141/4
import numpy as np
k = 4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_tanh = []
for i in range(k):
  print('processing fold#', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_1[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples], train[(i+1) * num_val_samples:]], axis=0)
  #print(partial_train_data)
  partial_train_targets = np.concatenate([train_1[:i * num_val_samples],train_1[(i+1) * num_val_samples:]], axis=0)
  model = build_model('tanh')
  model.fit(partial_train_data, partial_train_targets, epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data,val_targets,verbose=0)
  all_scores_tanh.append(val_mae)
# Out:
# processing fold# 0
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f8437f1c0e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold# 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f8437d6bb00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold# 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f84563ac440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold# 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f843795cef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
# Kfold validation with regularization

import numpy as np
k = 4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_regular = []
for i in range(k):
  print('processing fold#', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_1[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples], train[(i+1) * num_val_samples:]], axis=0)
  #print(partial_train_data)
  partial_train_targets = np.concatenate([train_1[:i * num_val_samples],train_1[(i+1) * num_val_samples:]], axis=0)
  model = build_model_regular('relu')
  model.fit(partial_train_data, partial_train_targets, epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data,val_targets,verbose=0)
  all_scores_regular.append(val_mae)
# Out:
# processing fold# 0
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f8430201ef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold# 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f8437bd44d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold# 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f8437c28050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold# 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f8437c4ec20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
# Kfold validation with dropout

import numpy as np
k = 4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_drop = []
for i in range(k):
  print('processing fold#', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_1[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples], train[(i+1) * num_val_samples:]], axis=0)
  #print(partial_train_data)
  partial_train_targets = np.concatenate([train_1[:i * num_val_samples],train_1[(i+1) * num_val_samples:]], axis=0)
  model = build_model_drop('relu')
  model.fit(partial_train_data, partial_train_targets, epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data,val_targets,verbose=0)
  all_scores_drop.append(val_mae)
# Out:
# processing fold# 0
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f8437f237a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold# 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f8437cb9dd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold# 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f8437c77320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold# 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f8437c4ed40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
#Scores

# %%
all_scores_relu
# Out:
# [0.23564821481704712,
#  0.4062734544277191,
#  0.4468337595462799,
#  0.28373944759368896]

# %%
all_scores_tanh
# Out:
# [0.2999088764190674,
#  0.2820146083831787,
#  0.5869841575622559,
#  0.2491387575864792]

# %%
all_scores_regular
# Out:
# [0.25772523880004883,
#  0.26005232334136963,
#  0.3526152968406677,
#  0.36794182658195496]

# %%
all_scores_drop
# Out:
# [0.45980045199394226, 0.520238995552063, 0.4223061501979828, 0.259538471698761]

# %%
#Training on Training Data

# %%
model_tanh = build_model('tanh')
model_tanh.fit(train,train_1, epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_tanh.evaluate(test, test_1)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f84563ac560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6454 - mse: 0.6454

# %%
model_relu = build_model('relu')
model_relu.fit(train, train_1, epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_relu.evaluate(test, test_1)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f8437c28f80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 9ms/step - loss: 10961.9658 - mse: 10961.9658

# %%
model_regular = build_model_regular('relu')
model_regular.fit(train, train_1, epochs = 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_regular.evaluate(test, test_1)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f8437b99a70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 11ms/step - loss: 28202.7051 - mae: 110.6451

# %%
model_drop = build_model_drop('relu')
model_drop.fit(train, train_1, epochs = 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_drop.evaluate(test, test_1)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f8437bd9f80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 8ms/step - loss: 10403.7793 - mae: 74.3454

# %%
#Prediction

# %%
test_1
# Out:
# array([ 0.01414832,  0.3725343 ,  1.3658801 ,  2.122337  , -1.004718  ,
#        -0.7045773 , -0.5886972 , -0.97443527, -0.763189  , -0.52312535,
#        -0.05301089, -0.3704908 , -0.5449216 , -0.80397296, -0.5536523 ,
#        -0.26059392,  0.6062484 ,  1.4864004 ,  2.5404336 ,  3.367835  ,
#        -0.8779702 , -0.09159691,  0.18192424, -0.7802841 , -0.50065756,
#        -0.9622245 , -0.6813769 , -0.5409531 ,  0.01463675,  0.12453365,
#         0.46643507, -0.1806134 ,  0.2687428 ,  0.4299249 ,  0.45129374,
#        -0.07511237,  2.3382235 ,  2.200547  , -0.49870384,  0.20280465,
#         0.26019526, -0.68430746, -0.7224051 , -0.65524584, -0.98066276,
#        -0.7889537 , -0.7547636 , -0.6888255 , -0.6277716 , -0.4983375 ,
#        -0.6020069 , -0.4139611 , -0.22347318, -0.54107517,  0.28217462,
#        -0.68430746, -0.6574438 , -0.59638995, -0.01027321,  0.056886  ,
#        -0.1329914 , -0.05362143,  0.3181964 ,  0.6155285 ], dtype=float32)

# %%
def predict(model,m):
  print(f"the actual value price was : {test_1[m]* std_label + mean_label}")
  return(f"the pridcted price was : {(model.predict(test[m:m+1].reshape(1, test.shape[1]))) * std_label + mean_label} ")

# %%
x_tanh = predict(model_tanh,2)
x_tanh
# Out:
# the actual value price was : 24565.000309357743
# 'the pridcted price was : [[22188.895]] '

# %%
x_relu = predict(model_relu,2)
x_relu
# Out:
# the actual value price was : 24565.000309357743
# 'the pridcted price was : [[633761.5]] '

# %%
x_regular = predict(model_regular,2)
x_regular
# Out:
# the actual value price was : 24565.000309357743
# 'the pridcted price was : [[1063393.4]] '

# %%
x_drop = predict (model_drop,2)
x_drop
# Out:
# the actual value price was : 24565.000309357743
# 'the pridcted price was : [[1127469.6]] '

# %%
def plot_fn(mod):
  y_true = test_1* std_label + mean_label
  y_pred = mod.predict(test) * std_label + mean_label
  return y_true , y_pred.flatten()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
def plotting(mod, label):
  y_true, y_pred = plot_fn(mod)
  coef = np.polyfit(y_true,y_pred,1)
  poly1d_fn = np.poly1d(coef)
  plt.figure()
  plt.plot(y_true,y_pred, 'yo', y_true, poly1d_fn(y_true), '--k')
  plt.title(label)
  plt.xlabel('Thousand Dollar True')
  plt.ylabel('Thousand Dollar Predictions')
  plt.xlim(0, 50000)
  plt.ylim(0, 50000)

# %%
plot_list = []
for i,j in enumerate([model_relu, model_tanh, model_regular, model_drop]):
  list_name = ['model_relu', 'model_tanh', 'model_regular', 'model_drop']
  plot_list.append(plotting(j,list_name[i]))
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8437c48950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f84379f63b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
